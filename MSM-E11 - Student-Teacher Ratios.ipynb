# %% [markdown]
# ![v1.0%20Jupyter%20Notebook%20Header%20msmdesign-01.png](attachment:v1.0%20Jupyter%20Notebook%20Header%20msmdesign-01.png)

# %% [markdown]
# ![Subheader%20-%20MSM-E11%20-%20EDA-01-01.png](attachment:Subheader%20-%20MSM-E11%20-%20EDA-01-01.png)

# %% [markdown]
# # Exploratory Data Analysis by David White

# %% [markdown]
# **Catalogue Number:** MSM-E11

# %% [markdown]
# **Language:** Python

# %% [markdown]
# **Contact:** david@msmdesign.nyc

# %% [markdown]
# > ### What is Exploratory Data Analysis?
# > **Exploratory data analysis (EDA)** is a technique used by data scientists to inspect, characterize and briefly summarize the contents of a dataset. EDA is often the first step when encountering a new or unfamiliar dataset. EDA helps the data scientist become acquainted with a dataset and test some basic assumptions about the data. By the end of the EDA process, some initial insights can be drawn from the dataset and a framework for further analysis or modeling is established.

# %% [markdown]
# ## 0. About this Dataset

# %% [markdown]
# **Data Source: The City of New York** https://opendata.cityofnewyork.us/
#
# Dataset Name: 2018-19 Preliminary Class Size Report School Pupil-to-Teacher Ratio
# Agency Name: Department of Education (DOE)
# Update Frequency: Annually
# Dataset Description: Pupil-to-Teacher Ratio by school
# Dataset Keywords: Pupil-to-Teacher Ratio, school
# Dataset Category: Education
# Why is this data collected?: To meet the requirements of New York City Charter Section 522(c-f)
# How is this data collected?: Data is collected using the Automate The Schools (ATS) administrative system and Student Transcript and Academic Reporting System (STARS)
# How can this data be used?: Data can be used to compare Pupil-to-Teacher ratios by school

# %% [markdown]
# ## 1. Prepare the Workspace

# %%
# import libraries need for data analysis and visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset from GitHub repository and glimpse

df = pd.read_csv('https://raw.githubusercontent.com/davidwhitemsm/selected-open-datasources/master/MSM-DS23b-2018_-_2019_Class_Size_Pupil_to_Teacher_Ratio%20-%20MSM-023-2018_-_2019_Class_Size_Pupil_to_Teacher_Ratio.csv', encoding = 'utf-8')
df.head(10)
# Out:
#       DBN Community School District                  School Name  \
# 0  01M015                    CSD 01      PS 015 ROBERTO CLEMENTE
# 1  01M019                    CSD 01            PS 019 ASHER LEVY
# 2  01M020                    CSD 01           PS 020 ANNA SILVER
# 3  01M034                    CSD 01  PS 034 FRANKLIN D ROOSEVELT
# 4  01M063                    CSD 01      THE STAR ACADEMY - PS63
# 5  01M064                    CSD 01          PS 064 ROBERT SIMON
# 6  01M110                    CSD 01  PS 110 FLORENCE NIGHTINGALE
# 7  01M134                    CSD 01       PS 134 HENRIETTA SZOLD
# 8  01M140                    CSD 01         PS 140 NATHAN STRAUS
# 9  01M142                    CSD 01         PS 142 AMALIA CASTRO
#
#    School Pupil-Teacher Ratio
# 0                         7.2
# 1                         6.6
# 2                        11.3
# 3                         9.0
# 4                        11.4
# 5                        10.1
# 6                        15.2
# 7                        10.0
# 8                        12.2
# 9                         9.3

# %%
df.tail(10)
# Out:
#          DBN Community School District  \
# 1512  32K383                    CSD 32
# 1513  32K384                    CSD 32
# 1514  32K403                    CSD 32
# 1515  32K545                    CSD 32
# 1516  32K549                    CSD 32
# 1517  32K552                    CSD 32
# 1518  32K554                    CSD 32
# 1519  32K556                    CSD 32
# 1520  32K562                    CSD 32
# 1521  32K564                    CSD 32
#
#                                             School Name  \
# 1512                          JHS 383 PHILIPPA SCHUYLER
# 1513                        PS /IS 384 FRANCES E CARTER
# 1514               ACADEMY FOR ENVIRONMENTAL LEADERSHIP
# 1515      EBC HIGH SCHOOL FOR PUBLIC SERVICE - BUSHWICK
# 1516                 BUSHWICK SCHOOL FOR SOCIAL JUSTICE
# 1517                          ACADEMY OF URBAN PLANNING
# 1518               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 1519  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 1520      EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
# 1521                     BUSHWICK COMMUNITY HIGH SCHOOL
#
#       School Pupil-Teacher Ratio
# 1512                        15.3
# 1513                        13.3
# 1514                        11.8
# 1515                        14.0
# 1516                        10.6
# 1517                        10.8
# 1518                        23.6
# 1519                        10.1
# 1520                        11.7
# 1521                        11.7

# %% [markdown]
# ## 2. Describe the Characteristics of the Dataset

# %%
# find out how many rows and columns are in the dataset

df.shape
# Out:
# (1522, 4)

# %% [markdown]
# **TAKEAWAY:** There are 1522 rows and 4 columns in the dataset

# %%
# find out the names of each column in the dataset

df.columns
# Out:
# Index(['DBN', 'Community School District', 'School Name',
#        'School Pupil-Teacher Ratio'],
#       dtype='object')

# %%
# 'DBN' stands for 'District Borough Number'. It is a unique identifer for an NYC public school

# %%
# find out the type of data contained in each column and whethere or now any rows are missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522 entries, 0 to 1521
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DBN                         1522 non-null   object
#  1   Community School District   1522 non-null   object
#  2   School Name                 1522 non-null   object
#  3   School Pupil-Teacher Ratio  1522 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 47.7+ KB

# %% [markdown]
# **TAKEAWAY:** The 'School Pubil-Teacher Ratio' column is the onl column that contains numeric data. There are no blank entries in any column.

# %% [markdown]
# ## 3. Summarize the Dataset

# %%
# sumarize the dataset by calculating some basic summary statisitcs

df.describe()
# Out:
#        School Pupil-Teacher Ratio
# count                 1522.000000
# mean                    13.535283
# std                      2.631601
# min                      3.900000
# 25%                     11.900000
# 50%                     13.500000
# 75%                     15.275000
# max                     25.600000

# %%
# group the dataset by average student-teacher ratio by school district

ratio = df.groupby(['Community School District']).mean()

# %%
# list the average student-teacher ratio in each school district

ratio
# Out:
#                            School Pupil-Teacher Ratio
# Community School District
# CSD 01                                      11.682143
# CSD 02                                      14.188983
# CSD 03                                      13.311364
# CSD 04                                      12.134483
# CSD 05                                      11.674074
# CSD 06                                      12.689130
# CSD 07                                      11.935000
# CSD 08                                      12.725000
# CSD 09                                      12.121739
# CSD 10                                      13.272941
# CSD 11                                      13.608065
# CSD 12                                      12.219149
# CSD 13                                      12.975610
# CSD 14                                      13.178947
# CSD 15                                      12.959184
# CSD 16                                      11.266667
# CSD 17                                      13.751020
# CSD 18                                      13.118182
# CSD 19                                      13.028571
# CSD 20                                      14.486047
# CSD 21                                      14.562500
# CSD 22                                      14.510000
# CSD 23                                      12.417857
# CSD 24                                      14.912727
# CSD 25                                      14.791304
# CSD 26                                      15.718182
# CSD 27                                      13.990476
# CSD 28                                      15.446000
# CSD 29                                      14.871739
# CSD 30                                      14.626531
# CSD 31                                      14.031944
# CSD 32                                      12.600000

# %%
# group by the highest student teacher ratio per district

max = df.groupby(['Community School District']).max()

# %%
# list the max student-teacher ratio in each school district

max
# Out:
#                               DBN  \
# Community School District
# CSD 01                     01M839
# CSD 02                     02M933
# CSD 10                                           21.9
# CSD 11                                           17.9
# CSD 12                                           15.8
# CSD 13                                           21.8
# CSD 14                                           18.3
# CSD 15                                           20.4
# CSD 16                                           16.4
# CSD 17                                           20.6
# CSD 18                                           19.4
# CSD 19                                           17.0
# CSD 20                                           19.8
# CSD 21                                           23.4
# CSD 22                                           20.2
# CSD 23                                           18.9
# CSD 24                                           20.3
# CSD 25                                           20.0
# CSD 26                                           19.8
# CSD 27                                           18.2
# CSD 28                                           21.5
# CSD 29                                           19.5
# CSD 30                                           21.4
# CSD 31                                           20.7
# CSD 32                                           23.6

# %%
sort1 = df.sort_values('School Pupil-Teacher Ratio', ascending = False)

# %%
sort1.tail(5)
# Out:
#         DBN Community School District  \
# 774  15K896                    CSD 15
# 205  04M206                    CSD 04
# 520  10X396                    CSD 10
# 200  04M112                    CSD 04
# 86   02M347                    CSD 02
#
#                                            School Name  \
# 774            THE SCHOOL OF CREATIVITY AND INNOVATION
# 205                          PS 206 JOSE CELSO BARBOSA
# 520                                             PS 396
# 200                          PS 112 JOSE CELSO BARBOSA
# 86   THE 47 AMERICAN SIGN LANGUAGE & ENGLISH LOWER ...
#
#      School Pupil-Teacher Ratio
# 774                         6.0
# 205                         5.6
# 520                         4.9
# 200                         4.9
# 86                          3.9

# %%
sort1.head(5)
# Out:
#          DBN Community School District                           School Name  \
# 191   04M012                    CSD 04                    TAG YOUNG SCHOLARS
# 1518  32K554                    CSD 32  ALL CITY LEADERSHIP SECONDARY SCHOOL
# 977   21K098                    CSD 21                     IS 98 BAY ACADEMY
# 1012  21K728                    CSD 21               LIBERATION DIPLOMA PLUS
# 529   10X445                    CSD 10          BRONX HIGH SCHOOL OF SCIENCE
#
#       School Pupil-Teacher Ratio
# 191                         25.6
# 1518                        23.6
# 977                         23.4
# 1012                        22.9
# 529                         21.9

# %%
# group by the lowest student teacher ratio per district

min = df.groupby(['Community School District']).min()

# %%
# list the min student-teacher ratio in each school district

min
# Out:
#                               DBN  \
# Community School District
# CSD 01                     01M015
# CSD 02                     02M001
# CSD 03                     03M009
# CSD 04                     04M007
# CSD 05                     05M030
# CSD 06                     06M004
# CSD 07                     07X001
# CSD 08                     08X014
# CSD 09                     09X004
# CSD 10                     10X003
# CSD 11                     11X016
# CSD 12                     12X006
# CSD 13                     13K003
# CSD 14                     14K016
# CSD 15                     15K001
# CSD 16                     16K005
# CSD 17                     17K002
# CSD 18                     18K066
# CSD 19                     19K007
# CSD 20                     20K030
# CSD 21                     21K090
# CSD 22                     22K014
# CSD 23                     23K041
# CSD 24                     24Q005
# CSD 25                     25Q020
# CSD 26                     26Q018
# CSD 27                     27Q042
# CSD 28                     28Q008
# CSD 29                     29Q015
# CSD 30                     30Q002
# CSD 31                     31R001
# CSD 32                     32K045
#
#                                                                  School Name  \
# Community School District
# CSD 01                                        BARD HIGH SCHOOL EARLY COLLEGE
# CSD 02                     47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# CSD 03                                                    BEACON HIGH SCHOOL
# CSD 04                                         CENTRAL PARK EAST HIGH SCHOOL
# CSD 05                                             COLUMBIA SECONDARY SCHOOL
# CSD 06                                  A PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# CSD 07                         ACADEMY OF APPLIED MATHEMATICS AND TECHNOLOGY
# CSD 08                     ANTONIA PANTOJA PREPARATORY ACADEMY: A COLLEGE...
# CSD 09                                   ACADEMY FOR LANGUAGE AND TECHNOLOGY
# CSD 10                        ACADEMY FOR PERSONAL LEADERSHIP AND EXCELLENCE
# CSD 11                     ACADEMY FOR SCHOLARSHIP AND ENTREPRENEURSHIP: ...
# CSD 12                                                        ACCION ACADEMY
# CSD 13                                           ACADEMY OF ARTS AND LETTERS
# CSD 14                                                AUTOMOTIVE HIGH SCHOOL
# CSD 15                                        BROOKLYN FRONTIERS HIGH SCHOOL
# CSD 16                                            BOYS AND GIRLS HIGH SCHOOL
# CSD 17                     ACADEMY FOR COLLEGE PREPARATION AND CAREER EXP...
# CSD 18                          ACADEMY FOR CONSERVATION AND THE ENVIRONMENT
# CSD 19                                             ACADEMY FOR YOUNG WRITERS
# CSD 20                                            BROOKLYN SCHOOL OF INQUIRY
# CSD 21                                           ABRAHAM LINCOLN HIGH SCHOOL
# CSD 22                                                         ANDRIES HUDDE
# CSD 23                           BROOKLYN COLLEGIATE: A COLLEGE BOARD SCHOOL
# CSD 24                                     ACADEMY OF FINANCE AND ENTERPRISE
# CSD 25                                                          BELL ACADEMY
# CSD 26                                                   BAYSIDE HIGH SCHOOL
# CSD 27                     ACADEMY OF MEDICAL TECHNOLOGY: A COLLEGE BOARD...
# CSD 28                              CATHERINE & COUNT BASIE MIDDLE SCHOOL 72
# CSD 29                     BENJAMIN FRANKLIN HIGH SCHOOL FOR FINANCE & IN...
# CSD 30                            ACADEMY FOR CAREERS IN TELEVISION AND FILM
# CSD 31                                                   CONCORD HIGH SCHOOL
# CSD 32                                  ACADEMY FOR ENVIRONMENTAL LEADERSHIP
#
#                            School Pupil-Teacher Ratio
# Community School District
# CSD 01                                            6.6
# CSD 02                                            3.9
# CSD 03                                            6.7
# CSD 04                                            4.9
# CSD 05                                            6.7
# CSD 06                                            8.4
# CSD 07                                            8.9
# CSD 08                                            8.8
# CSD 09                                            7.6
# CSD 10                                            4.9
# CSD 11                                            9.1
# CSD 12                                            9.0
# CSD 13                                            7.5
# CSD 14                                            8.7
# CSD 15                                            6.0
# CSD 16                                            6.1
# CSD 17                                            8.1
# CSD 18                                            8.8
# CSD 19                                            9.8
# CSD 20                                            7.3
# CSD 21                                            7.1
# CSD 22                                           11.2
# CSD 23                                            7.9
# CSD 24                                           10.9
# CSD 25                                            8.5
# CSD 26                                            6.8
# CSD 27                                            8.3
# CSD 28                                           11.0
# CSD 29                                            9.2
# CSD 30                                            6.6
# CSD 31                                            8.4
# CSD 32                                           10.1

# %% [markdown]
# ## 4. Visualize the Dataset

# %%
plt.figure(figsize=(15, 20))
sns.barplot(x='School Pupil-Teacher Ratio' ,y='Community School District',color='#4f81bd', saturation=.85, ci=None,data=df)
# Out:
# <AxesSubplot:xlabel='School Pupil-Teacher Ratio', ylabel='Community School District'>

# %%
plt.figure(figsize=(15, 20))
ax = sns.boxplot(y=df['Community School District'],x=df['School Pupil-Teacher Ratio'], color='#4f81bd', saturation=.85)

# %% [markdown]
# ## 5. Key Insights

# %% [markdown]
# Overall, NYC public schools have an average student-teacher ratio of 13.5:1.

# %% [markdown]
# ***

# %% [markdown]
# # Next Steps

# %% [markdown]
# A possible next step in exploring this data would be to join exam results and examine the correlation, if any, of student-teacher ratios and performance on standardized exams.
