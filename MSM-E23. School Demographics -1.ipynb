# %% [markdown]
# ![v1.0%20Jupyter%20Notebook%20Header%20msmdesign-01.png](attachment:v1.0%20Jupyter%20Notebook%20Header%20msmdesign-01.png)

# %% [markdown]
# ![Subheader%20-%20MSM-E23%20-%20EDA-01.png](attachment:Subheader%20-%20MSM-E23%20-%20EDA-01.png)

# %% [markdown]
# **Catalogue Number:** MSM-E23

# %% [markdown]
# **Author:** David White

# %% [markdown]
# **Contact:** david@msmdesign.nyc | [msmdesign.nyc](https://msmdesign.nyc/)

# %% [markdown]
# **Acknowledgements:** NYC Open Data [https://opendata.cityofnewyork.us/]

# %% [markdown]
# **Language:** Python

# %% [markdown]
# **Libraries Used:** NumPy, pandas, matplotlib, seaborn

# %% [markdown]
# > ### What is Exploratory Data Analysis?
# > **Exploratory data analysis (EDA)** is a technique used by data scientists to inspect, characterize and briefly summarize the contents of a dataset. EDA is often the first step when encountering a new or unfamiliar dataset. EDA helps the data scientist become acquainted with a dataset and test some basic assumptions about the data. By the end of the EDA process, some initial insights can be drawn from the dataset and a framework for further analysis or modeling is established.

# %% [markdown]
# ## 0. About this Dataset

# %% [markdown]
# **Data Source: U.S. Department of Education National Center for Education Statistics Common Core of Data (CCD)**
#
# "Public Elementary/Secondary School Universe Survey" 2018-19 v.1a; "Public Elementary/Secondary School Universe Survey Geographic Data (EDGE)" 2018-19 v.1a. Data provided by the National Center for Education Statistics - [http://nces.ed.gov/ccd/elsi/]

# %% [markdown]
# ## 1. Prepare the Workspace

# %%
# import the libraries needed for data analysis and visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset from GitHub

data = pd.read_csv("https://raw.githubusercontent.com/davidwhitemsm/selected-open-datasources/master/MSM-DS26-ELSI_csv_export_Table%20ID%20140972.csv")

# %%
# confirm that the data has loaded by taking a glimpse at the first five rows of the dataset

data.head(5)
# Out:
#    State Name  \
# 0     ALABAMA
# 1      ALASKA
# 2     ARIZONA
# 3    ARKANSAS
# 4  CALIFORNIA
#
#   Total Number Operational Charter Schools [Public School] 2018-19  \
# 0                                                  2
# 1                                                 28
# 2                                                558
# 3                                                 85
# 4                                               1358
#
#    Total Number of Public Schools [Public School] 2018-19  \
# 0                                               1529
# 1                                                510
# 2                                               2434
# 3                                               1080
# 4                                              10437
#
#    Total Students All Grades (Includes AE) [Public School] 2018-19  \
# 0                                             739304
# 1                                             130963
# 2                                            1136253
# 3                                             491804
# 4                                            6171666
#
#   Free and Reduced Lunch Students [Public School] 2018-19  \
# 0                                             407040
# 1                                              45537
# 2                                                  †
# 3                                             314759
# 4                                            3667601
#
#    Total Race/Ethnicity [Public School] 2018-19  \
# 0                                        738495
# 1                                        130963
# 2                                       1135883
# 3                                        490772
# 4                                       6163584
#
#    Pupil/Teacher Ratio [State] 2018-19  \
# 0                                17.56
# 1                                17.10
# 2                                23.53
# 3                                13.03
# 4                                23.08
#
#    Full-Time Equivalent (FTE) Teachers [State] 2018-19  \
# 0                                           42113.64
# 1                                            7656.78
# 2                                           48510.41
# 3                                           38019.16
# 4                                          271805.20
#
#   Instructional Aides [State] 2018-19  Guidance Counselors [State] 2018-19  \
# 0                             6508.89                              1769.44
# 1                             2720.43                               313.74
# 2                            16383.78                              1261.63
# 3                             9270.08                              1346.17
# 4                            87747.71                             10254.16
#
#                       ...                      \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#    Two or More Races Students [Public School] 2018-19  \
# 0                                              17674
# 1                                              15041
# 2                                              37612
# 3                                              13498
# 4                                             275017
#
#   Male Students [State] 2018-19  Female Students [State] 2018-19  \
# 0                        379760                           359956
# 1                         67626                            63337
# 2                        584228                           556973
# 3                        253924                           241367
# 4                       3178223                          3008055
#
#   American Indian/Alaska Native Students [State] 2018-19  \
# 0                                               6918
# 1                                              29839
# 2                                              51012
# 3                                               3086
# 4                                              31358
#
#    Asian or Asian/Pacific Islander Students [State] 2018-19  \
# 0                                              10887
# 1                                               7599
# 2                                              33646
# 3                                               8136
# 4                                             723605
#
#   Hispanic Students [State] 2018-19  Black Students [State] 2018-19  \
# 0                             62089                          240190
# 1                              8750                            3572
# 2                            520742                           62570
# 3                             65392                          100026
# 4                           3374921                          334652
#
#    White Students [State] 2018-19  \
# 0                          401066
# 1                           62159
# 2                          431056
# 3                          300475
# 4                         1417055
#
#    Hawaiian Nat./Pacific Isl. Students [State] 2018-19  \
# 0                                                881
# 1                                               4003
# 2                                               4425
# 3                                               4304
# 4                                              28085
#
#    Two or More Races Students [State] 2018-19
# 0                                       17685
# 1                                       15041
# 2                                       37750
# 3                                       13872
# 4                                      276602
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 2. Describe the Characteristics of the Dataset

# %%
# determine the number of rows and columns in the dataset

data.shape
# Out:
# (51, 42)

# %% [markdown]
# **TAKEAWAY:** The dataset consists of 51 rows and 42 columns.

# %%
# list each of the columns contained in the dataset 

data.columns
# Out:
# Index(['State Name',
#        'Total Number Operational Charter Schools [Public School] 2018-19',
#        'Total Number of Public Schools [Public School] 2018-19',
#        'Total Students All Grades (Includes AE) [Public School] 2018-19',
#        'Free and Reduced Lunch Students [Public School] 2018-19',
#        'Total Race/Ethnicity [Public School] 2018-19',
#        'Pupil/Teacher Ratio [State] 2018-19',
#        'Full-Time Equivalent (FTE) Teachers [State] 2018-19',
#        'Instructional Aides [State] 2018-19',
#        'Guidance Counselors [State] 2018-19', 'Librarians [State] 2018-19',
#        'Library Support Staff [State] 2018-19',
#        'LEA Administrators [State] 2018-19',
#        'LEA Administrative Support Staff [State] 2018-19',
#        'School Administrators [State] 2018-19',
#        'All Other Support Staff [State] 2018-19',
#        'Student Support Services [State] 2018-19',
#        'Full-Time Equivalent (FTE) Staff [State] 2018-19',
#        'Instructional Coordinators [State] 2018-19',
#        'Elementary Guidance Counselors [State] 2018-19',
#        'Secondary Guidance Counselors [State] 2018-19',
#        'Other Guidance Counselors [State] 2018-19',
#        'School Administrative Support Staff [State] 2018-19',
#        'Total Students [State] 2018-19',
#        'Male Students [Public School] 2018-19',
#        'Female Students [Public School] 2018-19',
#        'American Indian/Alaska Native Students [Public School] 2018-19',
#        'Asian or Asian/Pacific Islander Students [Public School] 2018-19',
#        'Hispanic Students [Public School] 2018-19',
#        'Black Students [Public School] 2018-19',
#        'White Students [Public School] 2018-19',
#        'Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19',
#        'Two or More Races Students [Public School] 2018-19',
#        'Male Students [State] 2018-19', 'Female Students [State] 2018-19',
#        'American Indian/Alaska Native Students [State] 2018-19',
#        'Asian or Asian/Pacific Islander Students [State] 2018-19',
#        'Hispanic Students [State] 2018-19', 'Black Students [State] 2018-19',
#        'White Students [State] 2018-19',
#        'Hawaiian Nat./Pacific Isl. Students [State] 2018-19',
#        'Two or More Races Students [State] 2018-19'],
#       dtype='object')

# %% [markdown]
# **TAKEAWAY:** The dataset consists of:
# - student enrollment
# - school staffing
# - student demographic information

# %%
# list the datatype of each variable contained in the dataset and check to see which variables have missing data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 42 columns):
# State Name                                                          51 non-null object
# Total Number Operational Charter Schools [Public School] 2018-19    51 non-null object
# Total Number of Public Schools [Public School] 2018-19              51 non-null int64
# Total Students All Grades (Includes AE) [Public School] 2018-19     51 non-null int64
# Free and Reduced Lunch Students [Public School] 2018-19             51 non-null object
# Total Race/Ethnicity [Public School] 2018-19                        51 non-null int64
# Pupil/Teacher Ratio [State] 2018-19                                 51 non-null float64
# Full-Time Equivalent (FTE) Teachers [State] 2018-19                 51 non-null float64
# Instructional Aides [State] 2018-19                                 51 non-null object
# Guidance Counselors [State] 2018-19                                 51 non-null float64
# Librarians [State] 2018-19                                          51 non-null float64
# Library Support Staff [State] 2018-19                               51 non-null object
# LEA Administrators [State] 2018-19                                  51 non-null float64
# LEA Administrative Support Staff [State] 2018-19                    51 non-null object
# School Administrators [State] 2018-19                               51 non-null float64
# All Other Support Staff [State] 2018-19                             51 non-null object
# Student Support Services [State] 2018-19                            51 non-null float64
# Full-Time Equivalent (FTE) Staff [State] 2018-19                    51 non-null float64
# Instructional Coordinators [State] 2018-19                          51 non-null float64
# Elementary Guidance Counselors [State] 2018-19                      51 non-null float64
# Secondary Guidance Counselors [State] 2018-19                       51 non-null float64
# Other Guidance Counselors [State] 2018-19                           51 non-null object
# School Administrative Support Staff [State] 2018-19                 51 non-null object
# Total Students [State] 2018-19                                      51 non-null int64
# Male Students [Public School] 2018-19                               51 non-null int64
# Female Students [Public School] 2018-19                             51 non-null int64
# American Indian/Alaska Native Students [Public School] 2018-19      51 non-null int64
# Asian or Asian/Pacific Islander Students [Public School] 2018-19    51 non-null int64
# Hispanic Students [Public School] 2018-19                           51 non-null int64
# Black Students [Public School] 2018-19                              51 non-null int64
# White Students [Public School] 2018-19                              51 non-null int64
# Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19         51 non-null int64
# Two or More Races Students [Public School] 2018-19                  51 non-null int64
# Male Students [State] 2018-19                                       51 non-null int64
# Female Students [State] 2018-19                                     51 non-null int64
# American Indian/Alaska Native Students [State] 2018-19              51 non-null int64
# Asian or Asian/Pacific Islander Students [State] 2018-19            51 non-null int64
# Hispanic Students [State] 2018-19                                   51 non-null int64
# Black Students [State] 2018-19                                      51 non-null int64
# White Students [State] 2018-19                                      51 non-null int64
# Hawaiian Nat./Pacific Isl. Students [State] 2018-19                 51 non-null int64
# Two or More Races Students [State] 2018-19                          51 non-null int64
# dtypes: float64(11), int64(22), object(9)
# memory usage: 16.8+ KB

# %% [markdown]
# **TAKEAWAY:** There are 51 rows and 42 columns in the dataset. None of the rows are blank.

# %%
# the data set seems to have one row of data per U.S. State. 
# let's test this assumption by checking for unique values in the 'State' column.

print(data['State Name'].unique())
# Out:
# ['ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DELAWARE' 'DISTRICT OF COLUMBIA' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MARYLAND' 'MASSACHUSETTS' 'MICHIGAN' 'MINNESOTA'
#  'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA' 'NEVADA' 'NEW HAMPSHIRE'
#  'NEW JERSEY' 'NEW MEXICO' 'NEW YORK' 'NORTH CAROLINA' 'NORTH DAKOTA'
#  'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'RHODE ISLAND' 'SOUTH CAROLINA'
#  'SOUTH DAKOTA' 'TENNESSEE' 'TEXAS' 'UTAH' 'VERMONT' 'VIRGINIA'
#  'WASHINGTON' 'WEST VIRGINIA' 'WISCONSIN' 'WYOMING']

# %% [markdown]
# **TAKEAWAY:** The dataset contains one row for each US state plus the District of Columbia.

# %% [markdown]
# ## 3. Summarize the Dataset

# %%
# create a subset of columns containing demographic subgroup information and glipse

subgroups = pd.read_csv("https://raw.githubusercontent.com/davidwhitemsm/selected-open-datasources/master/MSM-DS26-ELSI_csv_export_Table%20ID%20140972.csv", 
                 usecols=['State Name','Male Students [Public School] 2018-19',
       'Female Students [Public School] 2018-19',
       'American Indian/Alaska Native Students [Public School] 2018-19',
       'Asian or Asian/Pacific Islander Students [Public School] 2018-19',
       'Hispanic Students [Public School] 2018-19',
       'Black Students [Public School] 2018-19',
       'White Students [Public School] 2018-19',
       'Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19','Two or More Races Students [Public School] 2018-19'])
subgroups.head()
# Out:
#    State Name  Male Students [Public School] 2018-19  \
# 0     ALABAMA                                 379125
# 1      ALASKA                                  67626
# 2     ARIZONA                                 581012
# 3    ARKANSAS                                 252133
# 4  CALIFORNIA                                3167866
#
#    Female Students [Public School] 2018-19  \
# 0                                   359370
# 1                                    63337
# 2                                   554871
# 3                                   239671
# 4                                  3003800
#
#    American Indian/Alaska Native Students [Public School] 2018-19  \
# 0                                               6916
# 1                                              29839
# 2                                              50877
# 3                                               2771
# 4                                              28381
#
#    Asian or Asian/Pacific Islander Students [Public School] 2018-19  \
# 0                                              10860
# 1                                               7599
# 2                                              33428
# 3                                               7750
# 4                                             721827
#
#    Hispanic Students [Public School] 2018-19  \
# 0                                      62038
# 1                                       8750
# 2                                     518080
# 3                                      64790
# 4                                    3368944
#
#    Black Students [Public School] 2018-19  \
# 0                                  239759
# 1                                    3572
# 2                                   62005
# 3                                   99667
# 4                                  331252
#
#    White Students [Public School] 2018-19  \
# 0                                  400367
# 1                                   62159
# 2                                  429470
# 3                                  298173
# 4                                 1412439
#
#    Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19  \
# 0                                                881
# 1                                               4003
# 2                                               4411
# 3                                               4123
# 4                                              25724
#
#    Two or More Races Students [Public School] 2018-19
# 0                                              17674
# 1                                              15041
# 2                                              37612
# 3                                              13498
# 4                                             275017

# %% [markdown]
# **TAKEAWAY:** The dataset contains totals per state of the number of students in (2) gender categories and (7) race/ethnicity categories.

# %%
# summary statistics on the dataset

subgroups.describe()
# Out:
#        Male Students [Public School] 2018-19  \
# count                           5.100000e+01
# mean                            5.067872e+05
# std                             6.029885e+05
# min                             4.352000e+04
# 25%                             1.489505e+05
# 50%                             3.588130e+05
# 75%                             5.806480e+05
# max                             3.167866e+06
#
#        Female Students [Public School] 2018-19  \
# count                             5.100000e+01
# mean                              4.802107e+05
# std                               5.722634e+05
# min                               4.013100e+04
# 25%                               1.399745e+05
# 50%                               3.399870e+05
# 75%                               5.494835e+05
# max                               3.003800e+06
#
#        American Indian/Alaska Native Students [Public School] 2018-19  \
# count                                          51.000000
# mean                                         9266.470588
# std                                         15524.656776
# min                                            81.000000
# 25%                                          1321.000000
# 50%                                          3536.000000
# 75%                                          8757.000000
# max                                         91839.000000
#
#        Asian or Asian/Pacific Islander Students [Public School] 2018-19  \
# count                                          51.000000
# mean                                        51948.647059
# std                                        109441.469833
# min                                           784.000000
# 25%                                          5657.500000
# 50%                                         18202.000000
# 75%                                         56638.000000
# max                                        721827.000000
#
#        Hispanic Students [Public School] 2018-19  \
# count                               5.100000e+01
# mean                                2.678522e+05
# std                                 6.122845e+05
# min                                 1.984000e+03
# 25%                                 3.235800e+04
# 50%                                 1.019080e+05
# 75%                                 2.074140e+05
# max                                 3.368944e+06
#
#        Black Students [Public School] 2018-19  \
# count                               51.000000
# mean                            149220.372549
# std                             176718.990591
# min                               1026.000000
# 25%                              11702.000000
# 50%                              64606.000000
# 75%                             253845.500000
# max                             686252.000000
#
#        White Students [Public School] 2018-19  \
# count                            5.100000e+01
# mean                             4.645937e+05
# std                              3.720976e+05
# min                              1.041600e+04
# 25%                              1.568200e+05
# 50%                              3.808300e+05
# 75%                              6.233425e+05
# max                              1.490748e+06
#
#        Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19  \
# count                                          51.000000
# mean                                         3442.078431
# std                                          7966.708748
# min                                            45.000000
# 25%                                           315.000000
# 50%                                          1006.000000
# 75%                                          2287.500000
# max                                         50431.000000
#
#        Two or More Races Students [Public School] 2018-19
# count                                          51.000000
# mean                                        39857.980392
# std                                         44985.124083
# min                                          2166.000000
# 25%                                         10309.500000
# 50%                                         29043.000000
# 75%                                         56602.500000
# max                                        275017.000000

# %%
subgroups.sum()
# Out:
# State Name                                                          ALABAMAALASKAARIZONAARKANSASCALIFORNIACOLORADO...
# Male Students [Public School] 2018-19                                                                        25846148
# Female Students [Public School] 2018-19                                                                      24490747
# American Indian/Alaska Native Students [Public School] 2018-19                                                 472590
# Asian or Asian/Pacific Islander Students [Public School] 2018-19                                              2649381
# Hispanic Students [Public School] 2018-19                                                                    13660463
# Black Students [Public School] 2018-19                                                                        7610239
# White Students [Public School] 2018-19                                                                       23694279
# Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19                                                    175546
# Two or More Races Students [Public School] 2018-19                                                            2032757
# dtype: object

# %% [markdown]
# **TAKEAWAY:** 2018-19 US public school total enrollments by demographic group are as follows:
# - 25.8 million male students
# - 24.4 million female students
# - 473K American Indian/Alaska Native students
# - 2.6 million Asian or Asian/Pacific Islander students
# - 13.7 million Hispanic students
# - 7.6 million Black students
# - 23.7 million White students
# - 176K Hawaiian Nat./Pacific Isl. students
# - 2 million multiracial students

# %%
# here is the same information presented in a pivot table format

states = subgroups.T
states
# Out:
#                                                          0       1        2   \
# State Name                                          ALABAMA  ALASKA  ARIZONA
# Male Students [Public School] 2018-19                379125   67626   581012
# Female Students [Public School] 2018-19              359370   63337   554871
# American Indian/Alaska Native Students [Public ...     6916   29839    50877
# Asian or Asian/Pacific Islander Students [Publi...    10860    7599    33428
# Hispanic Students [Public School] 2018-19             62038    8750   518080
# Black Students [Public School] 2018-19               239759    3572    62005
# White Students [Public School] 2018-19               400367   62159   429470
# Hawaiian Nat./Pacific Isl. Students [Public Sch...      881    4003     4411
# Two or More Races Students [Public School] 2018-19    17674   15041    37612
#
#                                                           3           4   \
# State Name                                          ARKANSAS  CALIFORNIA
# Male Students [Public School] 2018-19                 252133     3167866
# Female Students [Public School] 2018-19               239671     3003800
# American Indian/Alaska Native Students [Public ...      2771       28381
# Asian or Asian/Pacific Islander Students [Publi...      7750      721827
# Hispanic Students [Public School] 2018-19              64790     3368944
# Black Students [Public School] 2018-19                 99667      331252
# White Students [Public School] 2018-19                298173     1412439
# Hawaiian Nat./Pacific Isl. Students [Public Sch...      4123       25724
# Two or More Races Students [Public School] 2018-19     13498      275017
#
#                                                           5            6   \
# State Name                                          COLORADO  CONNECTICUT
# Male Students [Public School] 2018-19                 468238       263177
# Female Students [Public School] 2018-19               443103       251521
# American Indian/Alaska Native Students [Public ...      5961          988
# Asian or Asian/Pacific Islander Students [Publi...     28743        26862
# Hispanic Students [Public School] 2018-19             305857       131082
# Black Students [Public School] 2018-19                 40847        64606
# White Students [Public School] 2018-19                486534       271805
# Hawaiian Nat./Pacific Isl. Students [Public Sch...      2002          303
# Two or More Races Students [Public School] 2018-19     39660        18276
#
#                                                           7   \
# State Name                                          DELAWARE
# Male Students [Public School] 2018-19                  70864
# Female Students [Public School] 2018-19                67541
# American Indian/Alaska Native Students [Public ...       540
# Asian or Asian/Pacific Islander Students [Publi...      5571
# Hispanic Students [Public School] 2018-19              24473
# Black Students [Public School] 2018-19                 41709
# White Students [Public School] 2018-19                 60267
# Hawaiian Nat./Pacific Isl. Students [Public Sch...       116
# Two or More Races Students [Public School] 2018-19      5597
#
#                                                                       8   \
# State Name                                          DISTRICT OF COLUMBIA
# Male Students [Public School] 2018-19                              44456
# Female Students [Public School] 2018-19                            43270
# American Indian/Alaska Native Students [Public ...                    81
# Asian or Asian/Pacific Islander Students [Publi...                  1308
# Hispanic Students [Public School] 2018-19                          14389
# Black Students [Public School] 2018-19                             59064
# White Students [Public School] 2018-19                             10416
# Hawaiian Nat./Pacific Isl. Students [Public Sch...                    45
# Two or More Races Students [Public School] 2018-19                  2166
#
#                                                          9    ...     \
# State Name                                          FLORIDA   ...
# Male Students [Public School] 2018-19               1462206   ...
# Female Students [Public School] 2018-19             1384223   ...
# American Indian/Alaska Native Students [Public ...     8126   ...
# Asian or Asian/Pacific Islander Students [Publi...    78933   ...
# Hispanic Students [Public School] 2018-19            964117   ...
# Black Students [Public School] 2018-19               624312   ...
# White Students [Public School] 2018-19              1063746   ...
# Hawaiian Nat./Pacific Isl. Students [Public Sch...     4839   ...
# Two or More Races Students [Public School] 2018-19   102356   ...
#
#                                                               41         42  \
# State Name                                          SOUTH DAKOTA  TENNESSEE
# Male Students [Public School] 2018-19                      71106     516533
# Female Students [Public School] 2018-19                    67338     489776
# American Indian/Alaska Native Students [Public ...         14915       1167
# Asian or Asian/Pacific Islander Students [Publi...          2416      19748
# Hispanic Students [Public School] 2018-19                   8959     109112
# Black Students [Public School] 2018-19                      4488     219853
# White Students [Public School] 2018-19                    101113     622666
# Hawaiian Nat./Pacific Isl. Students [Public Sch...           146        740
# Two or More Races Students [Public School] 2018-19          6407      31519
#
#                                                          43      44       45  \
# State Name                                            TEXAS    UTAH  VERMONT
# Male Students [Public School] 2018-19               2785567  348212    43520
# Female Students [Public School] 2018-19             2647904  328219    40131
# American Indian/Alaska Native Students [Public ...    20426    7124      221
# Asian or Asian/Pacific Islander Students [Publi...   242688   11584     1886
# Hispanic Students [Public School] 2018-19           2855160  117550     1984
# Black Students [Public School] 2018-19               686252    9498     2014
# White Students [Public School] 2018-19              1490748  500790    74934
# Hawaiian Nat./Pacific Isl. Students [Public Sch...     8271   10742       83
# Two or More Races Students [Public School] 2018-19   129926   19143     2267
#
#                                                           46          47  \
# State Name                                          VIRGINIA  WASHINGTON
# Male Students [Public School] 2018-19                 664584      580284
# Female Students [Public School] 2018-19               624783      544096
# American Indian/Alaska Native Students [Public ...      3408       12916
# Asian or Asian/Pacific Islander Students [Publi...     92045       88586
# Hispanic Students [Public School] 2018-19             208432      265990
# Black Students [Public School] 2018-19                285841       50069
# White Students [Public School] 2018-19                624019      598979
# Hawaiian Nat./Pacific Isl. Students [Public Sch...      2135       12347
# Two or More Races Students [Public School] 2018-19     73487       93836
#
#                                                                48         49  \
# State Name                                          WEST VIRGINIA  WISCONSIN
# Male Students [Public School] 2018-19                      138717     442788
# Female Students [Public School] 2018-19                    129259     416521
# American Indian/Alaska Native Students [Public ...            130       8918
# Asian or Asian/Pacific Islander Students [Publi...           1654      34298
# Hispanic Students [Public School] 2018-19                    4931     105749
# Black Students [Public School] 2018-19                      11108      77772
# White Students [Public School] 2018-19                     240394     595077
# Hawaiian Nat./Pacific Isl. Students [Public Sch...             48        311
# Two or More Races Students [Public School] 2018-19           9008      35033
#
#                                                          50
# State Name                                          WYOMING
# Male Students [Public School] 2018-19                 48786
# Female Students [Public School] 2018-19               45527
# American Indian/Alaska Native Students [Public ...     3442
# Asian or Asian/Pacific Islander Students [Publi...      784
# Hispanic Students [Public School] 2018-19             13050
# Black Students [Public School] 2018-19                 1026
# White Students [Public School] 2018-19                73237
# Hawaiian Nat./Pacific Isl. Students [Public Sch...      154
# Two or More Races Students [Public School] 2018-19     2620
#
# [10 rows x 51 columns]

# %% [markdown]
# ## 4. Visualize the Dataset

# %%
# plot Black public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='Black Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The states with the highest number of Black public school students are: Florida, Georgia and Texas.

# %%
# plot Hispanic public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='Hispanic Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The states with the highest number of Hispanic public school students are: California and Texas.

# %%
# plot Asian or Pacific Islander public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='Asian or Asian/Pacific Islander Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The state with the highest number of Asian or Asian/Pacific Islander public school students is California. New York and Texas are a distant second and third.

# %%
# plot American Indian/Alaska Native public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='American Indian/Alaska Native Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The state with the highest number of American Indian/Alaska Native public school students by far is Oklahoma.

# %%
# plot Hawaiian/Pacific Islander public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='Hawaiian Nat./Pacific Isl. Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The state with the highest number of Hawaiian/Pacific Islander public school students by far is Hawaii.

# %%
# plot White public school students by state

plt.figure(figsize=(18, 18))
sns.barplot(x='White Students [Public School] 2018-19',y='State Name', color='#4f81bd',data=subgroups)

# %% [markdown]
# **TAKEAWAY:** The states with the highest number of White public school students are: California and Texas.

# %% [markdown]
# ## 5. Key Insights

# %% [markdown]
# Populations of White students and populations of White students are mostly in portion with the state's overall population. However, for other demographic groups, students of that ethnicity are more heavily concentrated in just a handful of states.

# %% [markdown]
# ***

# %% [markdown]
# # Next Steps

# %% [markdown]
# Possible avenues for further research and analysis:
#
# - calculate each demographic group as a percentage of each state's overall public school population
# - compare this data to non-public school enrollments by state
# - compares education outcomes (graduation rates) accross states and demographic groups
